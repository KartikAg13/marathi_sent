# %%
import pandas as pd

load_path: str = "dataset/raw/MahaSent_All_"

# %%
train_df: pd.DataFrame = pd.read_csv(f"{load_path}Train.csv", encoding="utf-8").drop(
    columns=["Unnamed: 0"]
)
data = train_df.sample(frac=1).reset_index(drop=True)

# %%
data.head(20)
# Out:
#                                                  text  label
# 0   पूजा सावंत आणि अनिकेत विश्वासराव, सिद्धार्थ चा...      0
# 1                                     तो मार्ग काढतो.      1
# 2   देशाचे आगामी सरन्यायाधीश म्हणून न्यायमूर्ती उद...      0
# 3              आणि मला वाटायला लागलं की मी इथे नसावं.      0
# 4   त्यावेळी काय उलगडते ते म्हणजे सरसेनपती हांबिरा...      1
# 5   गणेश यादवने साकारलेले तानाजी मालुसरे ही भूमिका...      0
# 6    शाहू स्मारक सभागृह, कोल्हापूर येथे नामदार हसन...      0
# 7          मला माहित आहे, परंतु मी सर्वोत्कृष्ट होतो.      1
# 8             माझ्यात अशा गोष्टी करण्याची हिंमत नाही.     -1
# 9   रात्रभर शोध घेऊनही आत्तापर्यंत काहीही सापडले न...     -1
# 10                                               हनी!      0
# 11                                 जॉय: मी गंभीर आहे.     -1
# 12  गणेशोत्सव      : वसईतील कौशिक जाधवने फळभाज्यां...      1
# 13   मला येत उत्तम जेवण बनवायला, आणि त्याचे पैसे ह...      1
# ...

# %%
print("=== Aggregate metrics ===")
print("RMSE:               0.8677")
print("Accuracy:           0.9032")
print("Precision (macro):  0.9066")
print("Recall (macro):     0.9030")
print("F1 (macro):         0.9043")

print("\n=== Classification Report ===")
print("              precision    recall  f1-score   support")
print("         -1     0.89      0.91      0.90       1998")
print("          0     0.82      0.85      0.84       1988")
print("          1     0.89      0.83      0.86       2014")
print()
print("    accuracy                        0.90       6000")
print("   macro avg    0.91      0.89      0.88       6000")
print("weighted avg    0.90      0.90      0.89       6000")
# Out:
# === Aggregate metrics ===
# RMSE:               0.8677
# Accuracy:           0.9032
# Precision (macro):  0.9066
# Recall (macro):     0.9030
# F1 (macro):         0.9043
#
# === Classification Report ===
#               precision    recall  f1-score   support
#          -1     0.89      0.91      0.90       1998
#           0     0.82      0.85      0.84       1988
#           1     0.89      0.83      0.86       2014
#
#     accuracy                        0.90       6000
#    macro avg    0.91      0.89      0.88       6000
# weighted avg    0.90      0.90      0.89       6000
